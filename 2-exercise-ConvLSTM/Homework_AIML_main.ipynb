# %% [markdown]
# # Torch

# %%
# !pip3 install 'torch'
# !pip3 install 'torchvision'
# !pip install --upgrade pillow
# !pip3 install 'Pillow-SIMD'
# !pip3 install 'tqdm'
# !pip3 install "colorama"

import torch
#use GPU if available
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") #'cpu' # 'cuda' or 'cpu'
print(DEVICE)
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.16.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.31.0)
# Requirement already satisfied: torch==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.1.0+cu118)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.1.0->torchvision) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1.0->torchvision) (1.3.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)
# Collecting pillow
#   Downloading Pillow-10.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 27.3 MB/s eta 0:00:00
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
# Successfully installed pillow-10.1.0
# Requirement already satisfied: Pillow-SIMD in /usr/local/lib/python3.10/dist-packages (9.0.0.post1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (0.4.6)
# cuda:0

# %% [markdown]
# # Download Dataset GTEA61
#
# The GTEA61 dataset is a video-based dataset designed for action recognition and fine-grained analysis in the context of cooking activities. It focuses on the recognition of human actions while preparing tea, making it particularly relevant for tasks related to activity recognition and understanding in the kitchen environment.
#
# Key characteristics of the GTEA61 dataset include:
#
# 1. **Activities:** The dataset captures various activities related to tea preparation, such as pouring hot water, stirring, adding sugar, and others. These activities are performed by different individuals in a controlled environment.
#
# 2. **Videos:** The dataset consists of multiple video sequences, each depicting a specific instance of tea preparation. The videos are recorded from different viewpoints and under varying conditions to enhance the dataset's diversity.
#
# 3. **Annotations:** Ground truth annotations are provided for each video, indicating the temporal segments corresponding to different actions. This facilitates the training and evaluation of models for action recognition tasks.
#
# 4. **Challenges:** GTEA61 poses challenges typical of real-world scenarios, such as variations in object appearances, occlusions, and changes in illumination. This makes it suitable for assessing the robustness and generalization capabilities of action recognition algorithms.
#
# Researchers and practitioners in computer vision and machine learning often use datasets like GTEA61 to develop and evaluate algorithms for tasks like action recognition, temporal segmentation, and fine-grained activity analysis. These datasets play a crucial role in advancing the state-of-the-art in computer vision applications related to understanding human behavior from video data.

# %%
from google.colab import drive
import os
#drive.mount('/content/drive')
import sys, os

#1YKfdhB9Xxh4pmND1V3gcm3Gyjc8v8idq
if not os.path.isfile('/content/GTEA61.zip'):
  # !gdown --id 1Z5RWA8yKIy0PvxMlScV-aAz22ITtivfk # 3-5 min
  # !jar xvf  "/content/GTEA61.zip"

if not os.path.isdir('/content/GTEA61'):
  print("Dataset doesn't exist")

#Weights
if not os.path.isfile("/content/best_model_state_dict_rgb_split2.pth"):
  # !gdown --id 1B7Xh6hQ9Py8fmL-pjmLzlCent6dnuex5 # 3-5 min
# Out:
# Output streaming troncato alle ultime 5000 righe.
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0175.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0161.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0388.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0377.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0363.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0362.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0376.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0389.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0160.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0174.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0148.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0014.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0028.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0216.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0202.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0228.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0214.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0200.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0016.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0002.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0189.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0162.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0176.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0348.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0360.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0374.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0375.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0361.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0349.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0177.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0163.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0188.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0003.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0017.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0201.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0215.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0229.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0230.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0224.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0218.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0032.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0026.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0185.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0191.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0146.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0152.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0387.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0393.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0344.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0350.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0378.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0379.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0351.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0345.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0392.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0386.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0153.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0147.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0190.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0184.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0027.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0033.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0219.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0225.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0231.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0227.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0233.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0025.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0031.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0019.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0192.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0186.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0151.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0145.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0179.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0390.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0384.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0353.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0347.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0346.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0352.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0385.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0391.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0178.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0144.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0150.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0187.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0193.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0018.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0030.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0024.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0232.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0226.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0222.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0236.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0008.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0020.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0034.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0197.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0183.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0168.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0154.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0140.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0381.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0356.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0342.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0343.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0357.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0380.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0141.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0155.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0169.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0182.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0196.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0035.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0021.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0009.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0237.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0223.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0209.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0235.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0221.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0037.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0023.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0180.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0194.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0143.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0157.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0382.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0369.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0341.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0355.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0354.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0340.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0368.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0383.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0156.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0142.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0195.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0181.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0022.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0036.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0220.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0234.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0208.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0290.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0284.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0253.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0247.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0092.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0086.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0051.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0045.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0079.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0125.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0131.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0119.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0327.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0333.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0332.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0326.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0118.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0130.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0124.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0078.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0044.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0050.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0087.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0093.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0246.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0252.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0285.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0291.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0287.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0293.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0244.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0250.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0278.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0085.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0091.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0046.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0052.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0132.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0126.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0330.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0324.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0318.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0319.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0325.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0331.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0127.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0133.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0053.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0047.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0090.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0084.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0279.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0251.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0245.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0292.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0286.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0282.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0296.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0269.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0241.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0255.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0080.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0094.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0043.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0057.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0137.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0123.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0309.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0335.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0321.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0320.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0334.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0308.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0122.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0136.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0056.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0042.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0095.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0081.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0254.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0240.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0268.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0297.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0283.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0295.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0281.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0256.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0242.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0097.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0083.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0068.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0054.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0040.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0108.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0120.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0134.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0322.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0336.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0337.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0323.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0135.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0121.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0109.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0041.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0055.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0069.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0082.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0096.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0243.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0257.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0280.png
#  inflated: GTEA61/processed_frames2/S1/spread_peanut,spoon,bread/2/mmaps/map0294.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0027.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0033.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0032.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0026.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0018.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0030.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0024.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0025.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0031.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0019.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0035.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0021.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0009.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0008.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0020.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0034.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0022.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0036.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0037.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0023.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0044.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0050.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0051.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0045.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0053.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0047.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0046.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0052.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0056.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0042.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0043.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0057.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0041.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0055.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0054.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0040.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0048.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0049.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0006.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0012.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0013.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0007.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0039.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0011.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0005.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0004.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0010.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0038.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0014.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0028.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0029.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0001.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0015.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0003.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0017.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0016.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/rgb/rgb0002.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0049.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0048.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0013.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0007.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0006.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0012.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0004.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0010.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0038.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0039.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0011.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0005.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0029.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0001.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0015.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0014.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0028.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0016.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0002.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0003.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0017.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0032.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0026.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0027.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0033.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0025.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0031.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0019.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0018.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0030.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0024.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0008.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0020.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0034.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0035.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0021.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0009.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0037.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0023.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0022.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0036.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0051.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0045.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0044.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0050.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0046.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0052.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0053.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0047.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0043.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0057.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0056.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0042.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0054.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0040.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0041.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/1/mmaps/map0055.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0026.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0018.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0024.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0025.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0019.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0021.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0009.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0008.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0020.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0022.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0023.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0006.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0012.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0013.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0007.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0011.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0005.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0004.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0010.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0014.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0001.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0015.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0003.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0017.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0016.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/rgb/rgb0002.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0013.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0007.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0006.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0012.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0004.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0010.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0011.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0005.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0001.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0015.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0014.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0016.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0002.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0003.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0017.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0026.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0025.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0019.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0018.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0024.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0008.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0020.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0021.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0009.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0023.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/4/mmaps/map0022.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0027.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0033.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0032.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0026.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0018.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0030.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0024.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0025.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0031.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0019.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0035.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0021.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0009.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0008.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0020.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0034.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0022.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0036.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0037.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0023.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0006.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0012.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0013.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0007.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0039.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0011.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0005.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0004.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0010.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0038.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0014.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0028.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0029.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0001.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0015.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0003.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0017.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0016.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/rgb/rgb0002.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0013.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0007.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0006.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0012.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0004.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0010.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0038.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0039.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0011.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0005.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0029.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0001.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0015.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0014.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0028.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0016.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0002.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0003.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0017.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0032.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0026.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0027.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0033.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0025.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0031.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0019.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0018.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0030.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0024.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0008.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0020.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0034.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0035.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0021.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0009.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0037.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0023.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0022.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/3/mmaps/map0036.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0027.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0033.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0032.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0026.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0018.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0030.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0024.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0025.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0031.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0019.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0021.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0009.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0008.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0020.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0034.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0022.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0023.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0006.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0012.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0013.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0007.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0011.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0005.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0004.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0010.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0014.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0028.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0029.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0001.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0015.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0003.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0017.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0016.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/rgb/rgb0002.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0013.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0007.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0006.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0012.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0004.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0010.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0011.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0005.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0029.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0001.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0015.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0014.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0028.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0016.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0002.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0003.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0017.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0032.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0026.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0027.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0033.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0025.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0031.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0019.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0018.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0030.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0024.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0008.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0020.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0034.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0021.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0009.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0023.png
#  inflated: GTEA61/processed_frames2/S1/scoop_coffee,spoon/2/mmaps/map0022.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0027.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0033.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0032.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0026.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0018.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0030.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0024.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0025.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0031.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0019.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0035.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0021.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0009.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0008.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0020.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0034.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0022.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0036.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0037.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0023.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0042.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0041.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0040.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0006.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0012.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0013.png
#  inflated: GTEA61/processed_frames2/S1/scoop_sugar,spoon/1/rgb/rgb0007.png
# ...
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0063.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0088.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0049.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0075.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0061.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0129.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0101.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0115.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0114.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0100.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0128.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0060.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0074.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0048.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0013.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0007.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0006.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0012.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0004.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0010.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0038.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0039.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0011.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0005.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0029.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0001.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0015.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0014.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0028.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0016.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0002.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0003.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0017.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0032.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0026.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0027.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0033.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0025.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0031.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0019.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0018.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0030.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0024.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0008.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0020.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0034.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0035.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0021.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0009.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0037.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0023.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0022.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0036.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0092.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0086.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0051.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0045.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0079.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0125.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0131.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0119.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0118.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0130.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0124.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0078.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0044.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0050.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0087.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0093.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0085.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0091.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0046.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0052.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0132.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0126.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0127.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0133.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0053.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0047.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0090.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0084.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0080.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0094.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0043.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0057.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0123.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0122.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0056.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0042.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0095.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0081.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0097.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0083.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0068.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0054.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0040.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0108.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0120.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0121.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0109.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0041.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0055.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0069.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0082.png
#  inflated: GTEA61/processed_frames2/S1/pour_mustard,hotdog,bread/1/mmaps/map0096.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0027.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0033.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0032.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0026.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0018.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0030.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0024.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0025.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0031.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0019.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0035.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0021.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0009.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0008.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0020.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0034.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0022.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0036.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0037.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0023.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0041.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0040.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0006.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0012.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0013.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0007.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0039.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0011.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0005.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0004.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0010.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0038.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0014.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0028.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0029.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0001.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0015.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0003.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0017.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0016.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/rgb/rgb0002.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0013.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0007.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0006.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0012.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0004.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0010.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0038.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0039.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0011.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0005.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0029.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0001.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0015.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0014.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0028.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0016.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0002.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0003.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0017.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0032.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0026.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0027.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0033.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0025.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0031.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0019.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0018.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0030.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0024.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0008.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0020.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0034.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0035.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0021.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0009.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0037.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0023.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0022.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0036.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0040.png
#  inflated: GTEA61/processed_frames2/S1/put_bread,cheese,bread/1/mmaps/map0041.png
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1B7Xh6hQ9Py8fmL-pjmLzlCent6dnuex5
# To: /content/best_model_state_dict_rgb_split2.pth
# 100% 163M/163M [00:05<00:00, 32.0MB/s]

# %% [markdown]
# # Download Code

# %%
# !git clone "https://github.com/plana93/Homework_AIML.git"
#!rm -r "/content/Homework_AIML"
# Out:
# Cloning into 'Homework_AIML'...
# remote: Enumerating objects: 78, done.
# remote: Total 78 (delta 0), reused 0 (delta 0), pack-reused 78
# Receiving objects: 100% (78/78), 734.41 KiB | 2.49 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %% [markdown]
# # Import Code

# %%
import os
import PIL
import logging
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.backends import cudnn
import torchvision
from colorama import init
from colorama import Fore, Back, Style

from torchvision.models import resnet34
from PIL import Image
from tqdm import tqdm

import sys
sys.path.append("/content/Homework_AIML/")
import Homework_AIML
from Homework_AIML import *

from gtea_dataset import GTEA61, GTEA61_flow, GTEA61_2Stream
from spatial_transforms import (Compose, ToTensor, CenterCrop, Scale, Normalize, MultiScaleCornerCrop,
                                RandomHorizontalFlip)

# %% [markdown]
# #**Learning without Temporal information** (avgpool)

# %% [markdown]
# #MAIN PARAMs

# %%
homework_step = 0 #--> Learning without Temporal information (avgpool)
#homework_step = 1 #--> Learning with Temporal information (LSTM)
#homework_step = 2 #--> Learning with Spatio-Temporal information (ConvLSTM)



DATA_DIR = '/content/GTEA61/' #path dataset
model_folder = '/content/saved_models/' + "/" + "homework_step"+ str(homework_step) + "/" #path to save model
if not os.path.isdir(model_folder):
    os.makedirs(model_folder)


# All this param can be change!

NUM_CLASSES = 61
BATCH_SIZE = 64
LR = 0.001            # The initial Learning Rate
MOMENTUM = 0.9       # Hyperparameter for SGD, keep this at 0.9 when using SGD
WEIGHT_DECAY = 4e-5  # Regularization, you can keep this at the default
NUM_EPOCHS = 200     # Total number of training epochs (iterations over dataset)
STEP_SIZE = [25, 75, 150] # How many epochs before decreasing learning rate (if using a step-down policy)
GAMMA = 0.1          # Multiplicative factor for learning rate step-down
MEM_SIZE = 512       # Dim of internal state of LSTM or ConvLSTM
SEQ_LEN = 3          # Num Frames

# this dictionary is needed for the logger class
parameters = {'DEVICE':DEVICE, 'NUM_CLASSES':NUM_CLASSES, 'BATCH_SIZE':BATCH_SIZE,
             'LR':LR, 'MOMENTUM':MOMENTUM, 'WEIGHT_DECAY':WEIGHT_DECAY, 'NUM_EPOCHS':NUM_EPOCHS,
             'STEP_SIZE':STEP_SIZE, 'GAMMA':GAMMA, 'MEM_SIZE':MEM_SIZE, 'SEQ_LEN':SEQ_LEN}

# %% [markdown]
# #Dataloaders & Preprocessing

# %%
# Normalize
normalize = Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
spatial_transform = Compose([Scale(256), RandomHorizontalFlip(), MultiScaleCornerCrop([1, 0.875, 0.75, 0.65625], 224),
                             ToTensor(), normalize])
spatial_transform_val = Compose([Scale(256), CenterCrop(224), ToTensor(), normalize])

# %%
# Prepare Pytorch train/test Datasets
train_dataset = GTEA61(DATA_DIR, split='train', transform=spatial_transform, seq_len=SEQ_LEN)
test_dataset = GTEA61(DATA_DIR, split='test', transform=spatial_transform_val, seq_len=SEQ_LEN)

# Check dataset sizes
print('Train Dataset: {}'.format(len(train_dataset)))
print('Test Dataset: {}'.format(len(test_dataset)))

# Dataloaders iterate over pytorch datasets and transparently provide useful functions (e.g. parallelization and shuffling)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, drop_last=True)
val_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)
# Out:
# ['S1', 'S3', 'S2', 'S4']
# ['S1', 'S3', 'S2', 'S4']
# Train Dataset: 341
# Test Dataset: 116
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# #Model

# %%
import torch
import resnetMod
import torch.nn as nn
from torch.nn import functional as F
from torch.autograd import Variable



# LSTM
class MyLSTMCell(nn.Module):

    def __init__(self, input_size, hidden_size):
        super(MyLSTMCell, self).__init__()


    def forward(self, x, state):
        if state is None:
            state = (Variable(torch.randn(x.size(0), x.size(1)).cuda()),
                     Variable(torch.randn(x.size(0), x.size(1)).cuda()))

        ##################################
        # You should implement this part #
        ##################################

        return  None, None


#ConvLSTM
class MyConvLSTMCell(nn.Module):

    def __init__(self, input_size, hidden_size, kernel_size=3, stride=1, padding=1):
        super(MyConvLSTMCell, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.kernel_size = kernel_size
        self.stride = stride
        self.padding = padding
        self.conv_i_xx = nn.Conv2d(input_size, hidden_size, kernel_size=kernel_size, stride=stride, padding=padding)
        self.conv_i_hh = nn.Conv2d(hidden_size, hidden_size, kernel_size=kernel_size, stride=stride, padding=padding,
                                   bias=False)

        self.conv_f_xx = nn.Conv2d(input_size, hidden_size, kernel_size=kernel_size, stride=stride, padding=padding)
        self.conv_f_hh = nn.Conv2d(hidden_size, hidden_size, kernel_size=kernel_size, stride=stride, padding=padding,
                                   bias=False)

        self.conv_c_xx = nn.Conv2d(input_size, hidden_size, kernel_size=kernel_size, stride=stride, padding=padding)
        self.conv_c_hh = nn.Conv2d(hidden_size, hidden_size, kernel_size=kernel_size, stride=stride, padding=padding,
                                   bias=False)

        self.conv_o_xx = nn.Conv2d(input_size, hidden_size, kernel_size=kernel_size, stride=stride, padding=padding)
        self.conv_o_hh = nn.Conv2d(hidden_size, hidden_size, kernel_size=kernel_size, stride=stride, padding=padding,
                                   bias=False)

        torch.nn.init.xavier_normal_(self.conv_i_xx.weight)
        torch.nn.init.constant_(self.conv_i_xx.bias, 0)
        torch.nn.init.xavier_normal_(self.conv_i_hh.weight)

        torch.nn.init.xavier_normal_(self.conv_f_xx.weight)
        torch.nn.init.constant_(self.conv_f_xx.bias, 0)
        torch.nn.init.xavier_normal_(self.conv_f_hh.weight)

        torch.nn.init.xavier_normal_(self.conv_c_xx.weight)
        torch.nn.init.constant_(self.conv_c_xx.bias, 0)
        torch.nn.init.xavier_normal_(self.conv_c_hh.weight)

        torch.nn.init.xavier_normal_(self.conv_o_xx.weight)
        torch.nn.init.constant_(self.conv_o_xx.bias, 0)
        torch.nn.init.xavier_normal_(self.conv_o_hh.weight)

    def forward(self, x, state):
        if state is None:
            state = (Variable(torch.randn(x.size(0), x.size(1), x.size(2), x.size(3)).cuda()),
                     Variable(torch.randn(x.size(0), x.size(1), x.size(2), x.size(3)).cuda()))

        ##################################
        # You should implement this part #
        ##################################

        return  None, None




#Network
class ourModel(nn.Module):
    def __init__(self, num_classes=61, mem_size=512, homework_step = 0 , DEVICE=""):
        super(ourModel, self).__init__()
        self.DEVICE = DEVICE
        self.num_classes = num_classes
        self.resNet = resnetMod.resnet34(True, True)
        self.mem_size = mem_size
        self.weight_softmax = self.resNet.fc.weight
        self.homework_step = homework_step
        if self.homework_step == 1:
          self.lstm_cell = MyLSTMCell(512, mem_size)
        elif self.homework_step == 2:
          self.lstm_cell = MyConvLSTMCell(512, mem_size)

        self.avgpool = nn.AvgPool2d(7)
        self.dropout = nn.Dropout(0.7)
        self.fc = nn.Linear(mem_size, self.num_classes)
        self.classifier = nn.Sequential(self.dropout, self.fc)

    def forward(self, inputVariable):
        #Learning without Temporal information (mean)
        if self.homework_step == 0:
            video_level_features = torch.zeros((inputVariable.size(1), self.mem_size)).to(self.DEVICE)
            for t in range(inputVariable.size(0)):
                #spatial_frame_feat: (bs, 512, 7, 7)
                _, spatial_frame_feat, _ = self.resNet(inputVariable[t])
                #frames_feat: (bs, 512)
                frame_feat = self.avgpool(spatial_frame_feat).view(spatial_frame_feat.size(0), -1)
                video_level_features = video_level_features + frame_feat

            video_level_features = video_level_features / inputVariable.size(0)
            logits = self.classifier(video_level_features)
            return logits, video_level_features

        #Learning with Temporal information (LSTM)
        elif self.homework_step == 1:
            state = ( torch.zeros((inputVariable.size(1), self.mem_size)).to(self.DEVICE),
                     torch.zeros((inputVariable.size(1), self.mem_size)).to(self.DEVICE) )
            for t in range(inputVariable.size(0)):
                #spatial_frame_feat: (bs, 512, 7, 7)
                _, spatial_frame_feat, _ = self.resNet(inputVariable[t])
                #frames_feat: (bs, 512)
                frame_feat = self.avgpool(spatial_frame_feat).view(state[1].size(0), -1)
                state = self.lstm_cell(frame_feat, state)

            video_level_features = state[1]
            logits = self.classifier(video_level_features)
            return logits, video_level_features

        #Learning with Temporal information (ConvLSTM)
        elif self.homework_step == 2:
            state = (torch.zeros((inputVariable.size(1), self.mem_size, 7, 7)).to(self.DEVICE),
                     torch.zeros((inputVariable.size(1), self.mem_size, 7, 7)).to(self.DEVICE))
            for t in range(inputVariable.size(0)):
                #spatial_frame_feat: (bs, 512, 7, 7)
                _, spatial_frame_feat, _ = self.resNet(inputVariable[t])
                state = self.lstm_cell(spatial_frame_feat, state)
            video_level_features = self.avgpool(state[1]).view(state[1].size(0), -1)
            logits = self.classifier(video_level_features)
            return logits, video_level_features

# %% [markdown]
# #Build Model - Loss - Opt

# %%
#CUDA_LAUNCH_BLOCKING=1
validate = True

model = ourModel(num_classes=NUM_CLASSES, mem_size=MEM_SIZE, homework_step=homework_step, DEVICE=DEVICE) #model

#Train only the lstm cell and classifier
model.train(False)
for params in model.parameters():
    params.requires_grad = False

if homework_step > 0:
    for params in model.lstm_cell.parameters():
        params.requires_grad = True
    model.lstm_cell.train(True)

for params in model.classifier.parameters():
    params.requires_grad = True
model.classifier.train(True)


model = model.to(DEVICE)

#model.load_state_dict(torch.load("/content/best_model_state_dict_rgb_split2.pth", map_location=torch.device('cpu')), strict=True)


#Loss
loss_fn = nn.CrossEntropyLoss()
#Opt
trainable_params = [p for p in model.parameters() if p.requires_grad]
optimizer_fn = optim.Adam(trainable_params, lr=LR, weight_decay=WEIGHT_DECAY, eps=1e-4)
#Scheduler
optim_scheduler = optim.lr_scheduler.MultiStepLR(optimizer_fn, milestones=STEP_SIZE, gamma=GAMMA)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 197MB/s]

# %% [markdown]
# #Training

# %%
import warnings
# Suppress UserWarning
warnings.filterwarnings("ignore", category=UserWarning)

# %%
train_iter = 0
val_iter = 0
min_accuracy = 0

trainSamples = len(train_dataset) - (len(train_dataset) % BATCH_SIZE)
val_samples = len(test_dataset)
iterPerEpoch = len(train_loader)
val_steps = len(val_loader)
cudnn.benchmark
model_checkpoint = "model" #name


for epoch in range(NUM_EPOCHS):
    epoch_loss = 0
    numCorrTrain = 0

    #blocks to train
    if homework_step > 0:
        model.lstm_cell.train(True)
    model.classifier.train(True)


    for i, (inputs, targets) in enumerate(train_loader):
        train_iter += 1
        optimizer_fn.zero_grad()

        # (BS, Frames, C, W, H) --> (Frames, BS, C, W, H)
        inputVariable = inputs.permute(1, 0, 2, 3, 4).to(DEVICE)
        labelVariable = targets.to(DEVICE)

        # feeds in model
        output_label, _ = model(inputVariable)

        # compute loss
        loss = loss_fn(output_label, labelVariable)

        # backward loss and optimizer step
        loss.backward()
        optimizer_fn.step()

        #compute the training accuracy
        _, predicted = torch.max(output_label.data, 1)
        numCorrTrain += torch.sum(predicted == labelVariable.data).data.item()
        step_loss = loss.data.item()
        epoch_loss += step_loss

    avg_loss = epoch_loss/iterPerEpoch
    trainAccuracy = (numCorrTrain / trainSamples) * 100
    #train_logger.add_epoch_data(epoch+1, trainAccuracy, avg_loss)
    print(Fore.BLACK + 'Train: Epoch = {} | Loss = {:.3f} | Accuracy = {:.3f}'.format(epoch+1, avg_loss, trainAccuracy))
    if validate:
        if (epoch+1) % 1 == 0:
            model.train(False)
            val_loss_epoch = 0
            numCorr = 0
            for j, (inputs, targets) in enumerate(val_loader):
                val_iter += 1
                inputVariable = inputs.permute(1, 0, 2, 3, 4).to(DEVICE)
                labelVariable = targets.to(DEVICE)

                output_label, _ = model(inputVariable)
                val_loss = loss_fn(output_label, labelVariable)
                val_loss_step = val_loss.data.item()
                val_loss_epoch += val_loss_step
                _, predicted = torch.max(output_label.data, 1)
                numCorr += torch.sum(predicted == labelVariable.data).data.item()
                #val_logger.add_step_data(val_iter, numCorr, val_loss_step)

            val_accuracy = (numCorr / val_samples) * 100
            avg_val_loss = val_loss_epoch / val_steps

            print(Fore.GREEN + 'Val: Epoch = {} | Loss {:.3f} | Accuracy = {:.3f}'.format(epoch + 1, avg_val_loss, val_accuracy))
            if val_accuracy > min_accuracy:
                print("[||| NEW BEST on val||||]")
                save_path_model = os.path.join(model_folder, model_checkpoint)
                torch.save(model.state_dict(), save_path_model)
                min_accuracy = val_accuracy

    optim_scheduler.step()

print(Fore.CYAN + "Best Acc --> ", min_accuracy)
print(Fore.CYAN + "Last Acc --> ", val_accuracy)
# Out:
# Train: Epoch = 1 | Loss = 4.507 | Accuracy = 2.812
# Val: Epoch = 1 | Loss 4.043 | Accuracy = 6.034
# [||| NEW BEST on val||||]
# Train: Epoch = 2 | Loss = 4.532 | Accuracy = 3.125
# Val: Epoch = 2 | Loss 3.970 | Accuracy = 6.897
# [||| NEW BEST on val||||]
# Train: Epoch = 3 | Loss = 4.373 | Accuracy = 5.625
# Val: Epoch = 3 | Loss 3.892 | Accuracy = 6.897
# Train: Epoch = 4 | Loss = 4.266 | Accuracy = 5.312
# Val: Epoch = 4 | Loss 3.830 | Accuracy = 7.759
# [||| NEW BEST on val||||]
# Train: Epoch = 5 | Loss = 4.271 | Accuracy = 5.938
# Val: Epoch = 5 | Loss 3.771 | Accuracy = 8.621
# [||| NEW BEST on val||||]
# Train: Epoch = 6 | Loss = 4.196 | Accuracy = 5.625
# Val: Epoch = 6 | Loss 3.722 | Accuracy = 9.483
# [||| NEW BEST on val||||]
# Train: Epoch = 7 | Loss = 4.211 | Accuracy = 7.187
# Val: Epoch = 7 | Loss 3.687 | Accuracy = 9.483
# Train: Epoch = 8 | Loss = 4.141 | Accuracy = 5.312
# Val: Epoch = 8 | Loss 3.652 | Accuracy = 12.931
# [||| NEW BEST on val||||]
# Train: Epoch = 9 | Loss = 4.117 | Accuracy = 5.000
# Val: Epoch = 9 | Loss 3.622 | Accuracy = 12.931
# Train: Epoch = 10 | Loss = 4.038 | Accuracy = 7.187
# Val: Epoch = 10 | Loss 3.584 | Accuracy = 12.069
# Train: Epoch = 11 | Loss = 4.103 | Accuracy = 6.875
# Val: Epoch = 11 | Loss 3.546 | Accuracy = 15.517
# [||| NEW BEST on val||||]
# Train: Epoch = 12 | Loss = 4.058 | Accuracy = 7.812
# Val: Epoch = 12 | Loss 3.517 | Accuracy = 15.517
# Train: Epoch = 13 | Loss = 3.971 | Accuracy = 6.875
# Val: Epoch = 13 | Loss 3.499 | Accuracy = 16.379
# [||| NEW BEST on val||||]
# Train: Epoch = 14 | Loss = 3.971 | Accuracy = 6.250
# Val: Epoch = 14 | Loss 3.472 | Accuracy = 17.241
# [||| NEW BEST on val||||]
# Train: Epoch = 15 | Loss = 3.900 | Accuracy = 9.062
# Val: Epoch = 15 | Loss 3.441 | Accuracy = 18.103
# [||| NEW BEST on val||||]
# Train: Epoch = 16 | Loss = 3.812 | Accuracy = 10.312
# Val: Epoch = 16 | Loss 3.418 | Accuracy = 19.828
# [||| NEW BEST on val||||]
# Train: Epoch = 17 | Loss = 3.783 | Accuracy = 10.625
# Val: Epoch = 17 | Loss 3.394 | Accuracy = 22.414
# [||| NEW BEST on val||||]
# Train: Epoch = 18 | Loss = 3.835 | Accuracy = 7.500
# Val: Epoch = 18 | Loss 3.369 | Accuracy = 20.690
# Train: Epoch = 19 | Loss = 3.718 | Accuracy = 8.438
# Val: Epoch = 19 | Loss 3.349 | Accuracy = 18.966
# Train: Epoch = 20 | Loss = 3.780 | Accuracy = 10.625
# Val: Epoch = 20 | Loss 3.322 | Accuracy = 21.552
# Train: Epoch = 21 | Loss = 3.677 | Accuracy = 12.188
# Val: Epoch = 21 | Loss 3.293 | Accuracy = 24.138
# [||| NEW BEST on val||||]
# Train: Epoch = 22 | Loss = 3.676 | Accuracy = 12.812
# Val: Epoch = 22 | Loss 3.280 | Accuracy = 20.690
# Train: Epoch = 23 | Loss = 3.633 | Accuracy = 13.438
# Val: Epoch = 23 | Loss 3.261 | Accuracy = 20.690
# Train: Epoch = 24 | Loss = 3.663 | Accuracy = 12.188
# Val: Epoch = 24 | Loss 3.240 | Accuracy = 24.138
# Train: Epoch = 25 | Loss = 3.592 | Accuracy = 14.062
# Val: Epoch = 25 | Loss 3.237 | Accuracy = 25.000
# [||| NEW BEST on val||||]
# Train: Epoch = 26 | Loss = 3.575 | Accuracy = 11.562
# Val: Epoch = 26 | Loss 3.234 | Accuracy = 25.000
# Train: Epoch = 27 | Loss = 3.577 | Accuracy = 14.688
# Val: Epoch = 27 | Loss 3.230 | Accuracy = 25.000
# Train: Epoch = 28 | Loss = 3.590 | Accuracy = 11.562
# Val: Epoch = 28 | Loss 3.226 | Accuracy = 25.000
# Train: Epoch = 29 | Loss = 3.642 | Accuracy = 13.438
# Val: Epoch = 29 | Loss 3.222 | Accuracy = 25.862
# [||| NEW BEST on val||||]
# Train: Epoch = 30 | Loss = 3.538 | Accuracy = 13.438
# Val: Epoch = 30 | Loss 3.218 | Accuracy = 25.000
# Train: Epoch = 31 | Loss = 3.686 | Accuracy = 12.188
# Val: Epoch = 31 | Loss 3.215 | Accuracy = 25.000
# Train: Epoch = 32 | Loss = 3.629 | Accuracy = 12.500
# Val: Epoch = 32 | Loss 3.212 | Accuracy = 24.138
# Train: Epoch = 33 | Loss = 3.615 | Accuracy = 12.500
# Val: Epoch = 33 | Loss 3.210 | Accuracy = 24.138
# Train: Epoch = 34 | Loss = 3.523 | Accuracy = 14.062
# Val: Epoch = 34 | Loss 3.207 | Accuracy = 24.138
# Train: Epoch = 35 | Loss = 3.495 | Accuracy = 14.375
# Val: Epoch = 35 | Loss 3.204 | Accuracy = 23.276
# Train: Epoch = 36 | Loss = 3.524 | Accuracy = 12.812
# Val: Epoch = 36 | Loss 3.201 | Accuracy = 23.276
# Train: Epoch = 37 | Loss = 3.575 | Accuracy = 13.750
# Val: Epoch = 37 | Loss 3.199 | Accuracy = 23.276
# Train: Epoch = 38 | Loss = 3.577 | Accuracy = 14.375
# Val: Epoch = 38 | Loss 3.197 | Accuracy = 23.276
# Train: Epoch = 39 | Loss = 3.470 | Accuracy = 15.625
# Val: Epoch = 39 | Loss 3.195 | Accuracy = 23.276
# Train: Epoch = 40 | Loss = 3.560 | Accuracy = 10.625
# Val: Epoch = 40 | Loss 3.193 | Accuracy = 23.276
# Train: Epoch = 41 | Loss = 3.517 | Accuracy = 16.250
# Val: Epoch = 41 | Loss 3.191 | Accuracy = 24.138
# Train: Epoch = 42 | Loss = 3.499 | Accuracy = 13.438
# Val: Epoch = 42 | Loss 3.189 | Accuracy = 24.138
# Train: Epoch = 43 | Loss = 3.631 | Accuracy = 12.188
# Val: Epoch = 43 | Loss 3.187 | Accuracy = 23.276
# Train: Epoch = 44 | Loss = 3.534 | Accuracy = 13.438
# Val: Epoch = 44 | Loss 3.186 | Accuracy = 23.276
# Train: Epoch = 45 | Loss = 3.611 | Accuracy = 11.250
# Val: Epoch = 45 | Loss 3.185 | Accuracy = 24.138
# Train: Epoch = 46 | Loss = 3.570 | Accuracy = 11.875
# Val: Epoch = 46 | Loss 3.183 | Accuracy = 24.138
# Train: Epoch = 47 | Loss = 3.633 | Accuracy = 10.625
# Val: Epoch = 47 | Loss 3.182 | Accuracy = 23.276
# Train: Epoch = 48 | Loss = 3.584 | Accuracy = 12.500
# Val: Epoch = 48 | Loss 3.179 | Accuracy = 23.276
# Train: Epoch = 49 | Loss = 3.631 | Accuracy = 10.938
# Val: Epoch = 49 | Loss 3.177 | Accuracy = 23.276
# Train: Epoch = 50 | Loss = 3.602 | Accuracy = 14.062
# Val: Epoch = 50 | Loss 3.176 | Accuracy = 23.276
# Train: Epoch = 51 | Loss = 3.538 | Accuracy = 13.125
# Val: Epoch = 51 | Loss 3.175 | Accuracy = 23.276
# Train: Epoch = 52 | Loss = 3.525 | Accuracy = 12.500
# Val: Epoch = 52 | Loss 3.174 | Accuracy = 23.276
# Train: Epoch = 53 | Loss = 3.459 | Accuracy = 13.125
# Val: Epoch = 53 | Loss 3.172 | Accuracy = 24.138
# Train: Epoch = 54 | Loss = 3.401 | Accuracy = 16.562
# Val: Epoch = 54 | Loss 3.169 | Accuracy = 24.138
# Train: Epoch = 55 | Loss = 3.496 | Accuracy = 14.375
# Val: Epoch = 55 | Loss 3.168 | Accuracy = 23.276
# Train: Epoch = 56 | Loss = 3.472 | Accuracy = 13.125
# Val: Epoch = 56 | Loss 3.166 | Accuracy = 24.138
# Train: Epoch = 57 | Loss = 3.583 | Accuracy = 11.875
# Val: Epoch = 57 | Loss 3.164 | Accuracy = 24.138
# Train: Epoch = 58 | Loss = 3.575 | Accuracy = 13.125
# Val: Epoch = 58 | Loss 3.162 | Accuracy = 23.276
# Train: Epoch = 59 | Loss = 3.486 | Accuracy = 15.937
# Val: Epoch = 59 | Loss 3.160 | Accuracy = 23.276
# Train: Epoch = 60 | Loss = 3.565 | Accuracy = 13.750
# Val: Epoch = 60 | Loss 3.159 | Accuracy = 23.276
# Train: Epoch = 61 | Loss = 3.603 | Accuracy = 11.250
# Val: Epoch = 61 | Loss 3.158 | Accuracy = 23.276
# Train: Epoch = 62 | Loss = 3.447 | Accuracy = 13.125
# Val: Epoch = 62 | Loss 3.157 | Accuracy = 22.414
# Train: Epoch = 63 | Loss = 3.527 | Accuracy = 11.875
# Val: Epoch = 63 | Loss 3.157 | Accuracy = 22.414
# Train: Epoch = 64 | Loss = 3.401 | Accuracy = 15.625
# Val: Epoch = 64 | Loss 3.157 | Accuracy = 22.414
# Train: Epoch = 65 | Loss = 3.501 | Accuracy = 15.313
# Val: Epoch = 65 | Loss 3.156 | Accuracy = 22.414
# Train: Epoch = 66 | Loss = 3.598 | Accuracy = 9.375
# Val: Epoch = 66 | Loss 3.155 | Accuracy = 22.414
# Train: Epoch = 67 | Loss = 3.541 | Accuracy = 15.625
# Val: Epoch = 67 | Loss 3.153 | Accuracy = 23.276
# Train: Epoch = 68 | Loss = 3.469 | Accuracy = 14.688
# Val: Epoch = 68 | Loss 3.150 | Accuracy = 22.414
# Train: Epoch = 69 | Loss = 3.502 | Accuracy = 14.062
# Val: Epoch = 69 | Loss 3.148 | Accuracy = 23.276
# Train: Epoch = 70 | Loss = 3.456 | Accuracy = 15.937
# Val: Epoch = 70 | Loss 3.146 | Accuracy = 23.276
# Train: Epoch = 71 | Loss = 3.551 | Accuracy = 10.938
# Val: Epoch = 71 | Loss 3.144 | Accuracy = 22.414
# Train: Epoch = 72 | Loss = 3.523 | Accuracy = 13.438
# Val: Epoch = 72 | Loss 3.141 | Accuracy = 23.276
# Train: Epoch = 73 | Loss = 3.513 | Accuracy = 12.812
# Val: Epoch = 73 | Loss 3.139 | Accuracy = 23.276
# Train: Epoch = 74 | Loss = 3.586 | Accuracy = 9.375
# Val: Epoch = 74 | Loss 3.136 | Accuracy = 23.276
# Train: Epoch = 75 | Loss = 3.441 | Accuracy = 14.062
# Val: Epoch = 75 | Loss 3.136 | Accuracy = 23.276
# Train: Epoch = 76 | Loss = 3.472 | Accuracy = 10.938
# Val: Epoch = 76 | Loss 3.136 | Accuracy = 23.276
# Train: Epoch = 77 | Loss = 3.604 | Accuracy = 11.875
# Val: Epoch = 77 | Loss 3.136 | Accuracy = 23.276
# Train: Epoch = 78 | Loss = 3.484 | Accuracy = 17.812
# Val: Epoch = 78 | Loss 3.135 | Accuracy = 23.276
# Train: Epoch = 79 | Loss = 3.377 | Accuracy = 19.375
# Val: Epoch = 79 | Loss 3.135 | Accuracy = 23.276
# Train: Epoch = 80 | Loss = 3.496 | Accuracy = 16.250
# Val: Epoch = 80 | Loss 3.135 | Accuracy = 23.276
# Train: Epoch = 81 | Loss = 3.537 | Accuracy = 14.688
# Val: Epoch = 81 | Loss 3.135 | Accuracy = 23.276
# Train: Epoch = 82 | Loss = 3.464 | Accuracy = 15.937
# Val: Epoch = 82 | Loss 3.135 | Accuracy = 23.276
# Train: Epoch = 83 | Loss = 3.553 | Accuracy = 12.812
# Val: Epoch = 83 | Loss 3.134 | Accuracy = 23.276
# Train: Epoch = 84 | Loss = 3.387 | Accuracy = 16.875
# Val: Epoch = 84 | Loss 3.134 | Accuracy = 23.276
# Train: Epoch = 85 | Loss = 3.481 | Accuracy = 14.688
# Val: Epoch = 85 | Loss 3.134 | Accuracy = 23.276
# Train: Epoch = 86 | Loss = 3.502 | Accuracy = 15.937
# Val: Epoch = 86 | Loss 3.134 | Accuracy = 23.276
# Train: Epoch = 87 | Loss = 3.504 | Accuracy = 12.500
# Val: Epoch = 87 | Loss 3.134 | Accuracy = 23.276
# Train: Epoch = 88 | Loss = 3.559 | Accuracy = 13.750
# Val: Epoch = 88 | Loss 3.133 | Accuracy = 23.276
# Train: Epoch = 89 | Loss = 3.585 | Accuracy = 13.750
# Val: Epoch = 89 | Loss 3.133 | Accuracy = 23.276
# Train: Epoch = 90 | Loss = 3.379 | Accuracy = 15.937
# Val: Epoch = 90 | Loss 3.133 | Accuracy = 23.276
# Train: Epoch = 91 | Loss = 3.502 | Accuracy = 11.875
# Val: Epoch = 91 | Loss 3.133 | Accuracy = 23.276
# Train: Epoch = 92 | Loss = 3.550 | Accuracy = 10.938
# Val: Epoch = 92 | Loss 3.132 | Accuracy = 23.276
# Train: Epoch = 93 | Loss = 3.548 | Accuracy = 11.562
# Val: Epoch = 93 | Loss 3.132 | Accuracy = 23.276
# Train: Epoch = 94 | Loss = 3.480 | Accuracy = 15.313
# Val: Epoch = 94 | Loss 3.132 | Accuracy = 23.276
# Train: Epoch = 95 | Loss = 3.477 | Accuracy = 12.812
# Val: Epoch = 95 | Loss 3.132 | Accuracy = 23.276
# Train: Epoch = 96 | Loss = 3.528 | Accuracy = 11.250
# Val: Epoch = 96 | Loss 3.132 | Accuracy = 23.276
# Train: Epoch = 97 | Loss = 3.475 | Accuracy = 14.375
# Val: Epoch = 97 | Loss 3.132 | Accuracy = 23.276
# Train: Epoch = 98 | Loss = 3.551 | Accuracy = 11.875
# Val: Epoch = 98 | Loss 3.131 | Accuracy = 23.276
# Train: Epoch = 99 | Loss = 3.471 | Accuracy = 15.313
# Val: Epoch = 99 | Loss 3.131 | Accuracy = 23.276
# Train: Epoch = 100 | Loss = 3.499 | Accuracy = 15.000
# Val: Epoch = 100 | Loss 3.131 | Accuracy = 23.276
# Train: Epoch = 101 | Loss = 3.410 | Accuracy = 15.313
# Val: Epoch = 101 | Loss 3.131 | Accuracy = 23.276
# Train: Epoch = 102 | Loss = 3.510 | Accuracy = 13.750
# Val: Epoch = 102 | Loss 3.131 | Accuracy = 23.276
# Train: Epoch = 103 | Loss = 3.461 | Accuracy = 13.750
# Val: Epoch = 103 | Loss 3.131 | Accuracy = 23.276
# Train: Epoch = 104 | Loss = 3.411 | Accuracy = 17.188
# Val: Epoch = 104 | Loss 3.130 | Accuracy = 23.276
# Train: Epoch = 105 | Loss = 3.430 | Accuracy = 15.937
# Val: Epoch = 105 | Loss 3.130 | Accuracy = 23.276
# Train: Epoch = 106 | Loss = 3.461 | Accuracy = 13.750
# Val: Epoch = 106 | Loss 3.130 | Accuracy = 23.276
# Train: Epoch = 107 | Loss = 3.490 | Accuracy = 14.375
# Val: Epoch = 107 | Loss 3.130 | Accuracy = 24.138
# Train: Epoch = 108 | Loss = 3.602 | Accuracy = 11.250
# Val: Epoch = 108 | Loss 3.129 | Accuracy = 24.138
# Train: Epoch = 109 | Loss = 3.578 | Accuracy = 12.188
# Val: Epoch = 109 | Loss 3.129 | Accuracy = 24.138
# Train: Epoch = 110 | Loss = 3.457 | Accuracy = 16.875
# Val: Epoch = 110 | Loss 3.129 | Accuracy = 24.138
# Train: Epoch = 111 | Loss = 3.525 | Accuracy = 14.375
# Val: Epoch = 111 | Loss 3.129 | Accuracy = 24.138
# Train: Epoch = 112 | Loss = 3.517 | Accuracy = 14.375
# Val: Epoch = 112 | Loss 3.129 | Accuracy = 24.138
# Train: Epoch = 113 | Loss = 3.447 | Accuracy = 14.062
# Val: Epoch = 113 | Loss 3.128 | Accuracy = 25.000
# Train: Epoch = 114 | Loss = 3.597 | Accuracy = 12.188
# Val: Epoch = 114 | Loss 3.128 | Accuracy = 24.138
# Train: Epoch = 115 | Loss = 3.540 | Accuracy = 10.312
# Val: Epoch = 115 | Loss 3.128 | Accuracy = 25.000
# Train: Epoch = 116 | Loss = 3.481 | Accuracy = 14.375
# Val: Epoch = 116 | Loss 3.128 | Accuracy = 25.000
# Train: Epoch = 117 | Loss = 3.474 | Accuracy = 13.125
# Val: Epoch = 117 | Loss 3.128 | Accuracy = 25.000
# Train: Epoch = 118 | Loss = 3.464 | Accuracy = 14.375
# Val: Epoch = 118 | Loss 3.127 | Accuracy = 25.000
# Train: Epoch = 119 | Loss = 3.470 | Accuracy = 15.625
# Val: Epoch = 119 | Loss 3.127 | Accuracy = 25.000
# Train: Epoch = 120 | Loss = 3.413 | Accuracy = 15.000
# Val: Epoch = 120 | Loss 3.127 | Accuracy = 25.000
# Train: Epoch = 121 | Loss = 3.536 | Accuracy = 15.313
# Val: Epoch = 121 | Loss 3.127 | Accuracy = 25.000
# Train: Epoch = 122 | Loss = 3.528 | Accuracy = 13.438
# Val: Epoch = 122 | Loss 3.127 | Accuracy = 25.000
# Train: Epoch = 123 | Loss = 3.405 | Accuracy = 13.438
# Val: Epoch = 123 | Loss 3.127 | Accuracy = 25.000
# Train: Epoch = 124 | Loss = 3.482 | Accuracy = 11.875
# Val: Epoch = 124 | Loss 3.126 | Accuracy = 25.000
# Train: Epoch = 125 | Loss = 3.439 | Accuracy = 15.000
# Val: Epoch = 125 | Loss 3.126 | Accuracy = 25.000
# Train: Epoch = 126 | Loss = 3.539 | Accuracy = 14.062
# Val: Epoch = 126 | Loss 3.126 | Accuracy = 25.000
# Train: Epoch = 127 | Loss = 3.504 | Accuracy = 12.812
# Val: Epoch = 127 | Loss 3.126 | Accuracy = 25.000
# Train: Epoch = 128 | Loss = 3.491 | Accuracy = 11.875
# Val: Epoch = 128 | Loss 3.126 | Accuracy = 25.000
# Train: Epoch = 129 | Loss = 3.411 | Accuracy = 18.750
# Val: Epoch = 129 | Loss 3.125 | Accuracy = 25.000
# Train: Epoch = 130 | Loss = 3.445 | Accuracy = 15.937
# Val: Epoch = 130 | Loss 3.125 | Accuracy = 25.000
# Train: Epoch = 131 | Loss = 3.511 | Accuracy = 11.250
# Val: Epoch = 131 | Loss 3.125 | Accuracy = 25.000
# Train: Epoch = 132 | Loss = 3.519 | Accuracy = 12.812
# Val: Epoch = 132 | Loss 3.125 | Accuracy = 25.000
# Train: Epoch = 133 | Loss = 3.563 | Accuracy = 12.500
# Val: Epoch = 133 | Loss 3.125 | Accuracy = 25.000
# Train: Epoch = 134 | Loss = 3.530 | Accuracy = 13.438
# Val: Epoch = 134 | Loss 3.125 | Accuracy = 25.000
# Train: Epoch = 135 | Loss = 3.406 | Accuracy = 17.188
# Val: Epoch = 135 | Loss 3.125 | Accuracy = 25.000
# Train: Epoch = 136 | Loss = 3.594 | Accuracy = 11.562
# Val: Epoch = 136 | Loss 3.125 | Accuracy = 24.138
# Train: Epoch = 137 | Loss = 3.391 | Accuracy = 15.625
# Val: Epoch = 137 | Loss 3.125 | Accuracy = 25.000
# Train: Epoch = 138 | Loss = 3.489 | Accuracy = 17.500
# Val: Epoch = 138 | Loss 3.124 | Accuracy = 25.000
# Train: Epoch = 139 | Loss = 3.438 | Accuracy = 14.375
# Val: Epoch = 139 | Loss 3.124 | Accuracy = 24.138
# Train: Epoch = 140 | Loss = 3.356 | Accuracy = 20.312
# Val: Epoch = 140 | Loss 3.124 | Accuracy = 23.276
# Train: Epoch = 141 | Loss = 3.438 | Accuracy = 15.625
# Val: Epoch = 141 | Loss 3.124 | Accuracy = 23.276
# Train: Epoch = 142 | Loss = 3.488 | Accuracy = 13.438
# Val: Epoch = 142 | Loss 3.124 | Accuracy = 23.276
# Train: Epoch = 143 | Loss = 3.459 | Accuracy = 13.125
# Val: Epoch = 143 | Loss 3.123 | Accuracy = 23.276
# Train: Epoch = 144 | Loss = 3.566 | Accuracy = 13.125
# Val: Epoch = 144 | Loss 3.123 | Accuracy = 23.276
# Train: Epoch = 145 | Loss = 3.464 | Accuracy = 15.625
# Val: Epoch = 145 | Loss 3.123 | Accuracy = 23.276
# Train: Epoch = 146 | Loss = 3.579 | Accuracy = 13.438
# Val: Epoch = 146 | Loss 3.123 | Accuracy = 23.276
# Train: Epoch = 147 | Loss = 3.516 | Accuracy = 14.375
# Val: Epoch = 147 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 148 | Loss = 3.450 | Accuracy = 13.750
# Val: Epoch = 148 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 149 | Loss = 3.442 | Accuracy = 17.188
# Val: Epoch = 149 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 150 | Loss = 3.453 | Accuracy = 17.500
# Val: Epoch = 150 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 151 | Loss = 3.518 | Accuracy = 10.000
# Val: Epoch = 151 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 152 | Loss = 3.489 | Accuracy = 16.875
# Val: Epoch = 152 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 153 | Loss = 3.453 | Accuracy = 14.062
# Val: Epoch = 153 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 154 | Loss = 3.387 | Accuracy = 17.500
# Val: Epoch = 154 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 155 | Loss = 3.514 | Accuracy = 13.438
# Val: Epoch = 155 | Loss 3.122 | Accuracy = 24.138
# Train: Epoch = 156 | Loss = 3.475 | Accuracy = 14.062
# Val: Epoch = 156 | Loss 3.122 | Accuracy = 24.138
# Train: Epoch = 157 | Loss = 3.580 | Accuracy = 14.688
# Val: Epoch = 157 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 158 | Loss = 3.482 | Accuracy = 17.188
# Val: Epoch = 158 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 159 | Loss = 3.524 | Accuracy = 14.062
# Val: Epoch = 159 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 160 | Loss = 3.496 | Accuracy = 15.313
# Val: Epoch = 160 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 161 | Loss = 3.489 | Accuracy = 15.000
# Val: Epoch = 161 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 162 | Loss = 3.451 | Accuracy = 15.625
# Val: Epoch = 162 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 163 | Loss = 3.484 | Accuracy = 15.313
# Val: Epoch = 163 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 164 | Loss = 3.403 | Accuracy = 16.875
# Val: Epoch = 164 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 165 | Loss = 3.442 | Accuracy = 13.750
# Val: Epoch = 165 | Loss 3.122 | Accuracy = 24.138
# Train: Epoch = 166 | Loss = 3.381 | Accuracy = 14.688
# Val: Epoch = 166 | Loss 3.122 | Accuracy = 24.138
# Train: Epoch = 167 | Loss = 3.515 | Accuracy = 12.812
# Val: Epoch = 167 | Loss 3.122 | Accuracy = 24.138
# Train: Epoch = 168 | Loss = 3.453 | Accuracy = 18.125
# Val: Epoch = 168 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 169 | Loss = 3.470 | Accuracy = 17.188
# Val: Epoch = 169 | Loss 3.122 | Accuracy = 23.276
# Train: Epoch = 170 | Loss = 3.478 | Accuracy = 12.188
# Val: Epoch = 170 | Loss 3.121 | Accuracy = 23.276
# Train: Epoch = 171 | Loss = 3.496 | Accuracy = 13.125
# Val: Epoch = 171 | Loss 3.121 | Accuracy = 23.276
# Train: Epoch = 172 | Loss = 3.465 | Accuracy = 16.562
# Val: Epoch = 172 | Loss 3.121 | Accuracy = 23.276
# Train: Epoch = 173 | Loss = 3.480 | Accuracy = 11.875
# Val: Epoch = 173 | Loss 3.121 | Accuracy = 23.276
# Train: Epoch = 174 | Loss = 3.420 | Accuracy = 15.937
# Val: Epoch = 174 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 175 | Loss = 3.576 | Accuracy = 12.812
# Val: Epoch = 175 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 176 | Loss = 3.472 | Accuracy = 13.750
# Val: Epoch = 176 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 177 | Loss = 3.388 | Accuracy = 16.875
# Val: Epoch = 177 | Loss 3.121 | Accuracy = 25.000
# Train: Epoch = 178 | Loss = 3.463 | Accuracy = 15.625
# Val: Epoch = 178 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 179 | Loss = 3.475 | Accuracy = 15.313
# Val: Epoch = 179 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 180 | Loss = 3.423 | Accuracy = 17.188
# Val: Epoch = 180 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 181 | Loss = 3.433 | Accuracy = 17.188
# Val: Epoch = 181 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 182 | Loss = 3.557 | Accuracy = 10.625
# Val: Epoch = 182 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 183 | Loss = 3.520 | Accuracy = 15.313
# Val: Epoch = 183 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 184 | Loss = 3.524 | Accuracy = 10.625
# Val: Epoch = 184 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 185 | Loss = 3.423 | Accuracy = 12.812
# Val: Epoch = 185 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 186 | Loss = 3.438 | Accuracy = 13.438
# Val: Epoch = 186 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 187 | Loss = 3.427 | Accuracy = 13.750
# Val: Epoch = 187 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 188 | Loss = 3.389 | Accuracy = 17.500
# Val: Epoch = 188 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 189 | Loss = 3.463 | Accuracy = 14.688
# Val: Epoch = 189 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 190 | Loss = 3.489 | Accuracy = 15.000
# Val: Epoch = 190 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 191 | Loss = 3.356 | Accuracy = 15.313
# Val: Epoch = 191 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 192 | Loss = 3.456 | Accuracy = 15.313
# Val: Epoch = 192 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 193 | Loss = 3.496 | Accuracy = 16.875
# Val: Epoch = 193 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 194 | Loss = 3.528 | Accuracy = 14.688
# Val: Epoch = 194 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 195 | Loss = 3.498 | Accuracy = 14.062
# Val: Epoch = 195 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 196 | Loss = 3.594 | Accuracy = 8.750
# Val: Epoch = 196 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 197 | Loss = 3.474 | Accuracy = 13.438
# Val: Epoch = 197 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 198 | Loss = 3.418 | Accuracy = 15.313
# Val: Epoch = 198 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 199 | Loss = 3.443 | Accuracy = 16.250
# Val: Epoch = 199 | Loss 3.121 | Accuracy = 24.138
# Train: Epoch = 200 | Loss = 3.524 | Accuracy = 10.938
# Val: Epoch = 200 | Loss 3.121 | Accuracy = 24.138
# Best Acc -->  25.862068965517242
# Last Acc -->  24.137931034482758

# %% [markdown]
# #Test

# %%
model.train(False)
val_loss_epoch = 0
numCorr = 0
val_iter = 0
val_samples = len(test_dataset)
val_steps = len(val_loader)

with torch.no_grad():
    for j, (inputs, targets) in enumerate(val_loader):
        val_iter += 1
        inputVariable = inputs.permute(1, 0, 2, 3, 4).to(DEVICE)
        labelVariable = targets.to(DEVICE)

        output_label, _ = model(inputVariable)
        val_loss = loss_fn(output_label, labelVariable)
        val_loss_step = val_loss.data.item()
        val_loss_epoch += val_loss_step
        _, predicted = torch.max(output_label.data, 1)
        numCorr += torch.sum(predicted == labelVariable.data).data.item()

    val_accuracy = (numCorr / val_samples) * 100
    avg_val_loss = val_loss_epoch / val_steps

print('Loss {:.3f} | Accuracy = {:.3f}'.format(avg_val_loss, val_accuracy))
# Out:
# Loss 3.121 | Accuracy = 24.138

# %% [markdown]
# #**Learning with Temporal information** (LSTM)

# %% [markdown]
# #**Learning with Spatio-Temporal information** (ConvLSTM)
